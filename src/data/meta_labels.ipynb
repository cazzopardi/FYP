# %%
# imports
import os

import dask.dataframe as dd
from dask.distributed import Client, LocalCluster
import pandas as pd

from utils import dtype

# %%
# cluster setup
cluster = LocalCluster(n_workers=os.cpu_count())
client = Client(cluster)

# %%
dataset_part2: dd.DataFrame = dd.read_csv(os.path.join('..', '..', 'data','CSE-CIC-IDS-2018', 'raw_data', 'Tuesday-20-02-2018_TrafficForML_CICFlowMeter.csv'), dtype=dtype)
dataset_part1: dd.DataFrame = dd.read_csv(os.path.join('..', '..', 'data','CSE-CIC-IDS-2018','raw_data', 'uniform_files', '*.csv'), dtype=dtype)

extra_cols = dataset_part2.columns.difference(dataset_part1.columns)
for col in extra_cols:
    dataset_part1[col] = None
dataset: dd.DataFrame = dd.concat([dataset_part1, dataset_part2])  # type: ignore
dataset['Timestamp'] = dd.to_datetime(dataset['Timestamp'], dayfirst=True)

# %%
# attack labelling script

# note: this csv was generated from the table provided by the authors at: https://www.unb.ca/cic/datasets/ids-2018.html
attack_list: pd.DataFrame = pd.read_csv(os.path.join('..', '..', 'data','CSE-CIC-IDS-2018', 'attack_list.csv'))  
attack_list['start datetime'] = pd.to_datetime(attack_list['Date'] + ' ' + attack_list['Attack Start Time'] + ':00', dayfirst=True)
attack_list['end datetime'] = pd.to_datetime(attack_list['Date'] + ' ' + attack_list['Attack Finish Time'] + ':59', dayfirst=True)

dataset['attack name'] = 'Benign'
def label_attack(partition):
    for _, attack in attack_list.iterrows():
        is_part_of_attack = (attack['start datetime'] <= partition['Timestamp']) & (partition['Timestamp'] <= attack['end datetime']) & (partition['Label'] == attack['Attack Type'])
        partition.loc[is_part_of_attack, 'attack name'] = attack['Attack Name']
    return partition
metalabelled_dataset: dd.DataFrame = dataset.map_partitions(label_attack)  # type: ignore

# %%
metalabelled_dataset.to_csv(os.path.join('..', '..', 'data', 'CSE-CIC-IDS-2018', 'meta_labelled_data'), single_file=False, index=False)
# Out:
# ['/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/000.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/001.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/002.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/003.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/004.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/005.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/006.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/007.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/008.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/009.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/010.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/011.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/012.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/013.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/014.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/015.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/016.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/017.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/018.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/019.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/020.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/021.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/022.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/023.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/024.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/025.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/026.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/027.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/028.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/029.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/030.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/031.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/032.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/033.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/034.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/035.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/036.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/037.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/038.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/039.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/040.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/041.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/042.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/043.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/044.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/045.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/046.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/047.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/048.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/049.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/050.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/051.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/052.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/053.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/054.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/055.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/056.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/057.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/058.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/059.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/060.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/061.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/062.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/063.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/064.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/065.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/066.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/067.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/068.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/069.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/070.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/071.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/072.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/073.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/074.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/075.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/076.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/077.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/078.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/079.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/080.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/081.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/082.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/083.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/084.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/085.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/086.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/087.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/088.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/089.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/090.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/091.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/092.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/093.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/094.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/095.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/096.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/097.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/098.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/099.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/100.part',
#  '/Users/admin/Documents/Code/Git/FYP/data/meta_labelled_data/101.part']
