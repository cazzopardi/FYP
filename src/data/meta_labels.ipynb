# %%
# imports
import os

import dask.dataframe as dd
from dask.distributed import Client, LocalCluster
import pandas as pd
import numpy as np

from utils import dtype
# Out:
# /tmp/ipykernel_24110/3694996671.py:4: DeprecationWarning: The current Dask DataFrame implementation is deprecated.
# In a future release, Dask DataFrame will use a new implementation that
# contains several improvements including a logical query planning.
# The user-facing DataFrame API will remain unchanged.
#
# The new implementation is already available and can be enabled by
# installing the dask-expr library:
#
#     $ pip install dask-expr
#
# and turning the query planning option on:
#
#     >>> import dask
#     >>> dask.config.set({'dataframe.query-planning': True})
#     >>> import dask.dataframe as dd
#
# API documentation for the new implementation is available at
# https://docs.dask.org/en/stable/dask-expr-api.html
#
# Any feedback can be reported on the Dask issue tracker
# https://github.com/dask/dask/issues
#
# To disable this warning in the future, set dask config:
#
#     # via Python
#     >>> dask.config.set({'dataframe.query-planning-warning': False})
#
#     # via CLI
#     dask config set dataframe.query-planning-warning False
#
#
#   import dask.dataframe as dd

# %%
# cluster setup
cluster = LocalCluster(n_workers=os.cpu_count())
client = Client(cluster)
# Out:
# /home/calvin/FYP/venv/lib/python3.11/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 38743 instead
#   warnings.warn(

# %%
# dataset_part2: dd.DataFrame = dd.read_csv(os.path.join('..', '..', 'data','CSE-CIC-IDS-2018', 'raw_data', 'Tuesday-20-02-2018_TrafficForML_CICFlowMeter.csv'), dtype=dtype)
# dataset_part1: dd.DataFrame = dd.read_csv(os.path.join('..', '..', 'data','CSE-CIC-IDS-2018','raw_data', 'uniform_files', '*.csv'), dtype=dtype)

# extra_cols = dataset_part2.columns.difference(dataset_part1.columns)
# for col in extra_cols:
#     dataset_part1[col] = None
# dataset: dd.DataFrame = dd.concat([dataset_part1, dataset_part2])  # type: ignore
dataset: dd.DataFrame = dd.read_csv(os.path.join('..', '..', 'data','CSE-CIC-IDS-2018', 'meta_labelled_data', '*.part'), dtype=dtype)
dataset['Timestamp'] = dd.to_datetime(dataset['Timestamp'])

def parse_date_time(part):  # datetime disambiguation
    mask = part['Timestamp'].dt.hour < 8
    part.loc[mask, 'Timestamp'] += pd.Timedelta(hours=12)
    return part

dataset = dataset.map_partitions(parse_date_time)

# %%
# attack labelling script

# note: this csv was generated from the table provided by the authors at: https://www.unb.ca/cic/datasets/ids-2018.html
attack_list: pd.DataFrame = pd.read_csv(os.path.join('..', '..', 'data','CSE-CIC-IDS-2018', 'attack_list.csv'))  
attack_list['start datetime'] = pd.to_datetime(attack_list['Date'] + ' ' + attack_list['Attack Start Time'] + ':00', dayfirst=True)
attack_list['end datetime'] = pd.to_datetime(attack_list['Date'] + ' ' + attack_list['Attack Finish Time'] + ':59', dayfirst=True)
attack_list['Date'] = pd.to_datetime(attack_list['Date'], dayfirst=True).dt.date

dataset['attack name'] = 'Benign'
dataset['attack category'] = 'Benign'
def label_attacks(partition, add_categories=True):
    for _, attack in attack_list.iterrows():
        if attack['Label'] in ['Infilteration', 'Bot']:
            is_correct_date = np.logical_and(attack['start datetime'] <= partition['Timestamp'], partition['Timestamp'] <= attack['end datetime'])  
        else:
            is_correct_date = attack['Date'] == partition['Timestamp'].dt.date
        is_part_of_attack = np.logical_and(partition['Label'] == attack['Label'], is_correct_date)
        partition.loc[is_part_of_attack, 'attack name'] = attack['Attack Name']  # attack label
        
        if add_categories:
            partition.loc[is_part_of_attack, 'attack category'] = attack['Attack Category']  # add category label
        
    partition.loc[(partition['Label'] != 'Benign') & partition['attack name'] == 'Benign', 'attack name'] = 'Unknown'
    if add_categories:
        partition.loc[(partition['Label'] != 'Benign') & partition['attack name'] == 'Benign', 'attack category'] = 'Unknown'
    return partition
metalabelled_dataset: dd.DataFrame = dataset.map_partitions(label_attacks) # type: ignore
# label_attacks(dataset.partitions[10].compute())

# %%
metalabelled_dataset.to_csv(os.path.join('..', '..', 'data', 'CSE-CIC-IDS-2018', 'meta_labelled_data2'), single_file=False, index=False)
# Out:
# 2024-03-13 21:39:50,468 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 903.58 MiB -- Worker memory limit: 1.25 GiB
# 2024-03-13 21:39:51,524 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 914.03 MiB -- Worker memory limit: 1.25 GiB
# 2024-03-13 21:40:35,570 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 904.64 MiB -- Worker memory limit: 1.25 GiB
# 2024-03-13 21:41:44,915 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 908.29 MiB -- Worker memory limit: 1.25 GiB
# 2024-03-13 21:41:52,162 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 915.73 MiB -- Worker memory limit: 1.25 GiB
# ['/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/000.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/001.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/002.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/003.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/004.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/005.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/006.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/007.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/008.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/009.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/010.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/011.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/012.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/013.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/014.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/015.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/016.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/017.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/018.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/019.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/020.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/021.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/022.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/023.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/024.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/025.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/026.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/027.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/028.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/029.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/030.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/031.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/032.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/033.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/034.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/035.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/036.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/037.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/038.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/039.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/040.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/041.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/042.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/043.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/044.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/045.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/046.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/047.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/048.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/049.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/050.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/051.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/052.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/053.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/054.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/055.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/056.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/057.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/058.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/059.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/060.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/061.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/062.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/063.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/064.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/065.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/066.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/067.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/068.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/069.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/070.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/071.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/072.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/073.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/074.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/075.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/076.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/077.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/078.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/079.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/080.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/081.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/082.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/083.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/084.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/085.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/086.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/087.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/088.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/089.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/090.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/091.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/092.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/093.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/094.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/095.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/096.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/097.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/098.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/099.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/100.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/101.part',
#  '/home/calvin/FYP/data/CSE-CIC-IDS-2018/meta_labelled_data2/102.part']
